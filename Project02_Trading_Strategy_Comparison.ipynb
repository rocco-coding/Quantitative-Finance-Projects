# %%
# Project 02: Trading Strategy Comparison

# Question:
# How does changing the probabilty of profitable trades
# affect long-term portfolio performance?

# %%
import matplotlib.pyplot as plt
import random
print("all good")
# Out:
# all good

# %%
portfolio_A = []
portfolio_B = []

trader_A = 100
trader_B = 100
days = 100

for i in range(days):
    gain_loss_A = random.choice([-1,1])
    gain_loss_B = random.choice([-1,-1,1,1,1])
    trader_A = trader_A + gain_loss_A
    trader_B = trader_B + gain_loss_B
    portfolio_A.append(trader_A)
    portfolio_B.append(trader_B)
    
print(portfolio_A)

print("")

print("Highest Value:",max(portfolio_A))
print("Lowest Value:",min(portfolio_A))
print("Final Value:",portfolio_A[-1])

print("")

print(portfolio_B)

print("")

print("Highest Value:",max(portfolio_B))
print("Lowest Value:",min(portfolio_B))
print("Final Value:",portfolio_B[-1])

print("")

plt.plot(portfolio_A)
plt.plot(portfolio_B)
plt.xlabel("Time")
plt.ylabel("Portfolio Value")
plt.title("Trader A (Blue) against Trader B (Orange)")
plt.show()
# Out:
# [99, 100, 101, 100, 99, 100, 99, 100, 99, 100, 101, 100, 99, 98, 97, 98, 97, 98, 99, 100, 101, 100, 99, 98, 99, 100, 101, 100, 101, 102, 103, 104, 105, 104, 105, 106, 107, 106, 107, 106, 105, 106, 105, 106, 107, 106, 105, 104, 103, 104, 105, 106, 105, 104, 105, 104, 105, 106, 107, 108, 109, 108, 107, 106, 107, 106, 107, 106, 105, 106, 107, 108, 107, 106, 105, 104, 103, 102, 103, 102, 101, 102, 103, 102, 103, 102, 103, 104, 105, 104, 105, 104, 105, 104, 105, 104, 105, 104, 103, 102]
#
# Highest Value: 109
# Lowest Value: 97
# Final Value: 102
#
# ...

# %%
# Conclusion

# Trader A had a 50% chance of profit on each trade
# whilst Trader B had a 60% chance of profit.

# The simulation demonstrated that just a small improvement in
# the proportion of profitable trades, results in a significant change
# in the growth of a portfolio over a given period.
