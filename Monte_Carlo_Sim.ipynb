# %%
import matplotlib.pyplot as plt
import random
print('all good')
# Out:
# all good

# %%
final_values = []
portfolio_num = 100
days = 100

for i in range(portfolio_num):
    equity_per = 100
    for i in range(days):
        profit_loss = random.choice([-1,1])
        equity_per = equity_per + profit_loss
    final_values.append(equity_per)
print(final_values)
print('')
print('Highest Value:',max(final_values))
print('Lowest Value:',min(final_values))
print('Average Value:',sum(final_values)/portfolio_num)
print('')

plt.hist(final_values)
plt.xlabel('Portfolio Value')
plt.ylabel('Number of Portfolios')
plt.title('Values of 100 Portfolios after 100 days')
plt.show()
# Out:
# [120, 116, 102, 92, 96, 100, 92, 104, 94, 90, 122, 98, 90, 92, 100, 94, 114, 106, 116, 112, 102, 94, 92, 92, 104, 96, 100, 100, 110, 114, 90, 108, 100, 92, 76, 92, 104, 100, 120, 96, 92, 94, 102, 90, 114, 90, 100, 104, 106, 80, 92, 98, 104, 110, 120, 106, 92, 116, 96, 86, 88, 88, 108, 104, 100, 78, 106, 126, 104, 80, 122, 92, 100, 86, 94, 104, 90, 92, 88, 100, 96, 90, 106, 108, 112, 102, 88, 88, 94, 112, 94, 92, 88, 96, 80, 116, 100, 98, 98, 94]
#
# Highest Value: 126
# Lowest Value: 76
# Average Value: 99.26
