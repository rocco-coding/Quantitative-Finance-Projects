# %%
# Project 01: Random Portfolio Simulator

# Question:
# How does a portfolio perform over time under
# equal but random P&L?

# %%
import matplotlib.pyplot as plt
import random
print("all good")
# Out:
# all good

# %%
portfolio_value = []

portfolio = 100
days = 50

for i in range(days):
    profit_loss = random.choice([-1,1])
    portfolio = portfolio + profit_loss
    portfolio_value.append(portfolio)
print(portfolio_value)

print(" ")

print("Highest Portfolio Value:",max(portfolio_value))
print("Lowest Portfolio Value:",min(portfolio_value))
print("Final Portfolio Value:",portfolio_value[-1])

print(" ")

plt.plot(portfolio_value)
plt.xlabel("Time")
plt.ylabel("Portfolio Value")
plt.title("Value of Portfolio Over 50 Days")
plt.show()
# Out:
# [99, 98, 99, 98, 97, 98, 99, 100, 101, 102, 101, 102, 103, 104, 103, 102, 103, 104, 103, 102, 101, 102, 103, 104, 103, 102, 103, 104, 103, 104, 103, 102, 101, 102, 103, 102, 101, 100, 99, 98, 99, 100, 99, 100, 99, 98, 99, 98, 99, 100]
#
# Highest Portfolio Value: 104
# Lowest Portfolio Value: 97
# Final Portfolio Value: 100

# %%
# Conclusion

# This simulation demonstrated how portfolio values can change under
# random market conditions.

# This project introduced portfolio tracking, compounding returns
# and data visualisation, providing a foundation for more advanced
# projects later on.
